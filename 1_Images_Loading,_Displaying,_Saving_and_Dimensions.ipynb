# %% [markdown]
# <a href="https://colab.research.google.com/github/mohankrishna12/OpenCV_Basics/blob/main/1_Images_Loading%2C_Displaying%2C_Saving_and_Dimensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import OpenCV
import cv2

# %%
# version
print(cv2.__version__)
# Out:
# 4.8.0

# %% [markdown]
# ### **Loading Images**

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('/content/drive/MyDrive/Images_CV/flowers.jpg')

# %% [markdown]
# ### **Displaying Images**

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Let's create a simple function to make displaying of images so that we can reuse whenever displaying is needed

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
#test the display function
imshow("Displaying Our First Image", image)

# %% [markdown]
# ### **Saving Images**

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output_flower.jpg', image)
# Out:
# True

# %%
# Or save it as a PNG (Portable Network Graphics) which is a Lossless bitmap image format
cv2.imwrite('output_flower.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions**
#
# Remember Images are arrays:
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/array.png?token=ADLZD2HNEL33JAKTYRM3B5C7WMIV4)

# %% [markdown]
# We need to use numpy to perform this operation.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (3072, 4096, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2.
image.shape[0]
# Out:
# 3072

# %% [markdown]
# You can see the first dimension is the height and it's 3072 pixels
#
# The second dimension is the width which is 4096 pixels.
#
# We can print them like this:

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 3072 pixels
# Width of Image: 4096 pixels
# Depth of Image: 3 colors components
