# %% [markdown]
# <a href="https://colab.research.google.com/github/mohankrishna12/OpenCV_Basics/blob/main/2_Grayscaling_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Grayscaling Images**
#
# 1. Convert a color image to grayscale
# 2. See the change in dimensions between grayscale and color images

# %%
import cv2
from matplotlib import pyplot as plt

# %%
# Define our imshow function
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Load our input image
image = cv2.imread('/content/drive/MyDrive/Images_CV/flowers.jpg')

imshow("Flowers", image)

# %%
print(image.shape[0]) #height
print(image.shape[1]) #width
print(image.shape[2]) #depth
# Out:
# 3072
# 4096
# 3

# %%
image.shape[:2] # (3072, 4096) (height, width)
def imshow(title = "", image = None, size = 10):

    # The line below is changed from w, h to h, w
    h, w = image.shape[0], image.shape[1]
    aspect_ratio = w/h

    plt.figure(figsize=(size * aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

imshow("Flowers", image)

# %%
# We use cvtColor, to convert to grayscale
# It takes 2 arguments, the first being the input image
# The second being the color space conversion code
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

imshow("Converted to Grayscale", gray_image)

# %% [markdown]
# ### **Grayscale Image Dimensions**
#
# RGB color images have 3 dimensions, one for each primary color. Grayscale just has 1, which is the intensity of gray.
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/gray.png)

# %%
image.shape #shape before conversion
# Out:
# (3072, 4096, 3)

# %%
gray_image.shape #shape after grayscale conversion
# Out:
# (3072, 4096)
